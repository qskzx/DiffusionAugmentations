# %% [markdown]
# # Diffusion Augmentation — local run
#
# Локальный запуск (если есть CUDA и место на диске).

# %%
python -m venv .venv
source .venv/bin/activate
pip install -r requirements.txt
pip install -e .

# %% [markdown]
# ## Run

# %%
python -m diffaug_pets.scripts.run_pipeline --all --data_root ./data --work_dir ./work
